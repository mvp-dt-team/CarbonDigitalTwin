# %%
import json
import numpy as np

from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline


import pandas as pd
from PIL import Image
import torch
from sklearn.preprocessing import StandardScaler

from tqdm import tqdm

import time
import matplotlib.pyplot as plt
# import logging
from datetime import datetime
import torch.nn as nn



from matplotlib.colors import LinearSegmentedColormap
import os
import zipfile

# %%
import os

def list_files_in_directory(directory):
    """
    Функция, которая возвращает список названий файлов в указанной папке.

    Параметры:
     - directory: Строка, путь к папке, в которой нужно найти файлы.
     
    Возвращает:
     - Список строк с названиями файлов.
    """
    file_list = []
    for filename in os.listdir(directory):
        if os.path.isfile(os.path.join(directory, filename)):
            file_list.append(filename)
    return file_list

# Пример использования
directory_path = 'dataset_1_geometry'  # Замените на свой путь к папке
files = list_files_in_directory(directory_path)
print("Список файлов в папке:", files)
# Out:
# Список файлов в папке: ['dataset_0.json', 'dataset_1.json', 'dataset_10.json', 'dataset_11.json', 'dataset_12.json', 'dataset_13.json', 'dataset_14.json', 'dataset_15.json', 'dataset_16.json', 'dataset_17.json', 'dataset_18.json', 'dataset_19.json', 'dataset_2.json', 'dataset_20.json', 'dataset_21.json', 'dataset_22.json', 'dataset_23.json', 'dataset_24.json', 'dataset_25.json', 'dataset_26.json', 'dataset_27.json', 'dataset_28.json', 'dataset_29.json', 'dataset_3.json', 'dataset_30.json', 'dataset_31.json', 'dataset_32.json', 'dataset_4.json', 'dataset_5.json', 'dataset_6.json', 'dataset_7.json', 'dataset_8.json', 'dataset_9.json']

# %%
dataset = []
for nameoffile in files:
    name = 'dataset_1_geometry/'+nameoffile
    with open(name, 'r') as file:
        data = json.load(file)

    # Создание датасета
    
    for item in data:
        input_values = item['input']
        output_value = item['output'][0]
        dataset.append(input_values + [output_value])

# Преобразование в numpy массив
dataset = np.array(dataset)

# %%
print(len(dataset))
# Out:
# 34500

# %%
X = dataset[:, :-1]
y = dataset[:, -1]
# Предварительно обработаем X, чтобы избежать бесконечных значений после логарифмического преобразования
X_processed = np.where(X <= 0, 1e-10, X)  # Заменяем нулевые значения на небольшое положительное число

# Применяем логарифмическое преобразование к данным
X_log = np.log(X_processed)

# Создаем модель полиномиальной регрессии
degree = 7  # Можно выбрать другую степень полинома
model = make_pipeline(PolynomialFeatures(degree), LinearRegression())

# Обучаем модель
model.fit(X_log, y)
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures(degree=7)),
#                 ('linearregression', LinearRegression())])

# %%
new_data = np.array([[-1.0, 0.0, 0.0005879507104204, 1.0, 0.004975124378109453, 1.0, 0.011695906432748537]])
new_data_processed = np.where(new_data <= 0, 1e-10, new_data)  # Заменяем нулевые значения на небольшое положительное число
new_data_log = np.log(new_data_processed)
predicted_value = model.predict(new_data_log)[0]
print("Predicted value:", predicted_value)

# Обратное преобразование предсказанного числа
predicted_value_inv = np.exp(predicted_value) - 1
print("Inverse transformed predicted value:", predicted_value_inv)
# Out:
# Predicted value: 0.0002240897190404212
# Inverse transformed predicted value: 0.0002241148290171857

# %%
def max_width_spinneret(matrix_array):
    
    # Находим индексы элементов, не равных -1, для каждой строки 
    non_negative_indices = (matrix_array != -1)                          
                                                                            
    # Считаем количество элементов, не равных -1, для каждой строки      
    count_non_negative_elements = np.sum(non_negative_indices, axis=1)   
                                                                            
    # Находим индекс строки с максимальным количеством элементов, не равных -1
    max_row_index = np.argmax(count_non_negative_elements)
    max_width = count_non_negative_elements[max_row_index]
    
    return max_width

def heigh_of_col(mrx, index):
    column = mrx[:, index]
    mask = column != -1
    count_non_negative = np.sum(mask)
    return count_non_negative

def width_row(matrix_array, row):
    # Находим индексы элементов, не равных -1, в выбранной строке
    non_negative_indices_in_selected_row = (matrix_array[row] != -1)

    # Считаем количество элементов, не равных -1, в выбранной строке
    count_non_negative_elements_in_selected_row = np.sum(non_negative_indices_in_selected_row)
    
    return count_non_negative_elements_in_selected_row

def length_to_elements(matrix_array, row, column):
    selected_row_part = matrix_array[row, :column + 1]
    non_negative_indices_in_selected_row_part = (selected_row_part != -1)
    count_non_negative_elements_in_selected_row_part = np.sum(non_negative_indices_in_selected_row_part)
    
    return count_non_negative_elements_in_selected_row_part

def create_pandas_file(output_file: str):
    return pd.read_csv(output_file)

def create_matrices(columns, idx, pandas_file, step_x, step_y, matrixes):
      
    for col in columns[idx][2:3]:
        print(col)
        matrix = pd.pivot_table(pandas_file, values=col,
                                index='y',
                                columns='x',
                                fill_value=-1)
        print(matrix)
        matrixes.append(matrix.to_numpy())

# %%
files_name = ['Dataset_0.csv']
columns = []
step_x = 0.01
step_y = 0.01

for file in files_name:
    df = pd.read_csv(file)
    columns.append(list(df.columns))

matrixes = []
for idx, file in enumerate(files_name):
    df = create_pandas_file(file)
    create_matrices(columns, idx, df, step_x, step_y, matrixes)

mrx = np.flipud(matrixes[0])
file_path_float = 'mrx.txt'
np.savetxt(file_path_float, mrx, fmt='%f', delimiter='\t')
# Out:
# spf.U (m/s) @ v0=0.02_y2=3E-4
# x     -1.01  -1.00     -0.99     -0.98     -0.97     -0.96     -0.95  \
# y
# 0.00     -1     -1 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 0.01     -1     -1 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 0.02     -1     -1 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 0.03     -1     -1 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 0.04     -1     -1 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# ...     ...    ...       ...       ...       ...       ...       ...
# 1.96     -1      0  0.000587  0.001167  0.001743  0.002314  0.002877
# 1.97     -1      0  0.000587  0.001168  0.001744  0.002315  0.002878
# 1.98     -1      0  0.000587  0.001169  0.001745  0.002316  0.002880
# 1.99     -1      0  0.000588  0.001169  0.001745  0.002317  0.002881
# 2.00     -1      0  0.000588  0.001170  0.001746  0.002318  0.002882
#
# x        -0.94     -0.93     -0.92  ...      0.92      0.93      0.94  \
# y                                   ...
# 0.00 -1.000000 -1.000000 -1.000000  ... -1.000000 -1.000000 -1.000000
# 0.01 -1.000000 -1.000000 -1.000000  ... -1.000000 -1.000000 -1.000000
# 0.02 -1.000000 -1.000000 -1.000000  ... -1.000000 -1.000000 -1.000000
# 0.03 -1.000000 -1.000000 -1.000000  ... -1.000000 -1.000000 -1.000000
# 0.04 -1.000000 -1.000000 -1.000000  ... -1.000000 -1.000000 -1.000000
# ...        ...       ...       ...  ...       ...       ...       ...
# 1.96  0.003435  0.003990  0.004536  ...  0.004536  0.003990  0.003435
# 1.97  0.003437  0.003992  0.004539  ...  0.004538  0.003991  0.003437
# 1.98  0.003439  0.003994  0.004540  ...  0.004540  0.003993  0.003439
# 1.99  0.003440  0.003995  0.004543  ...  0.004542  0.003995  0.003440
# 2.00  0.003442  0.003997  0.004545  ...  0.004544  0.003997  0.003442
#
# x         0.95      0.96      0.97      0.98      0.99   1.00   1.01
# y
# 0.00 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000     -1     -1
# 0.01 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000     -1     -1
# 0.02 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000     -1     -1
# 0.03 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000     -1     -1
# 0.04 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000     -1     -1
# ...        ...       ...       ...       ...       ...    ...    ...
# 1.96  0.002877  0.002313  0.001743  0.001167  0.000587      0     -1
# 1.97  0.002878  0.002315  0.001744  0.001168  0.000587      0     -1
# 1.98  0.002879  0.002316  0.001745  0.001169  0.000587      0     -1
# 1.99  0.002881  0.002317  0.001745  0.001169  0.000588      0     -1
# 2.00  0.002882  0.002318  0.001746  0.001170  0.000588      0     -1
#
# [201 rows x 203 columns]

# %%
empty_matrix = np.flipud((matrixes[0].copy()))
full_matrix = np.flipud((matrixes[0].copy()))
num_rows, num_cols = empty_matrix.shape

for i in range(1, num_rows):
    for j in range(num_cols):
        if empty_matrix[i, j] != -1:
            empty_matrix[i, j] = 0

file_path_float = 'empty pattern.txt'
full_path = 'full patter.txt'
# Сохранение массива с числами с плавающей запятой в текстовый файл
np.savetxt(file_path_float, empty_matrix, fmt='%f', delimiter='\t')
np.savetxt(full_path, full_matrix, fmt='%f', delimiter='\t')

# %%
def process_matrix(matrix_array, emrx, ml_name):
    # Задаем форму матрицы 3x3
    max_width = max_width_spinneret(matrix_array)

    # Используем nditer для итерации по матрицам 3x3
    it = np.nditer(matrix_array, flags=['multi_index'], op_flags=['readwrite'], order='C')
    while not it.finished:
        # Получаем текущий индекс
        i, j = it.multi_index
        if matrix_array[i, j] != -1:
            width_of_row = width_row(matrix_array, i)
            length_to_element = length_to_elements(matrix_array, i, j)
            width_of_previous_row = width_row(matrix_array, i-1)
            hgt_c = heigh_of_col(mrx, j) 
            # Проверяем, что матрица 2x3 целиком помещается внутри массива
            if i - 1 >= 0 and j - 1 >= 0 and j + 1 < matrix_array.shape[1]:
                # Выполняем операции над матрицей 3x3
                submatrix = matrix_array[i - 1 : i + 1, j - 1 : j + 2]
                # Ваш код для обработки submatrix
                             
                outer = []
                d4_to_d1 = width_of_previous_row / max_width
                d2_to_d1 = width_of_row / max_width
                d3_to_d2 = length_to_element / width_of_row
                dyn_dy = (i + 1) / hgt_c 
                for x_offset, y_offset in [(0, 0), (0, 1), (0, 2)]:
                    outer_value = submatrix[x_offset, y_offset]
                    outer.append(outer_value)

                outer.append(d2_to_d1)
                outer.append(d3_to_d2)
                outer.append(d4_to_d1)    
                outer.append(dyn_dy)

                new_data = np.array([outer])
                new_data_processed = np.where(new_data <= 0, 1e-10, new_data)  # Заменяем нулевые значения на небольшое положительное число
                new_data_log = np.log(new_data_processed)
                predicted_value = ml_name.predict(new_data_log)[0]
                print("Predicted value:", predicted_value)

                # Обратное преобразование предсказанного числа
                predicted_value_inv = np.exp(predicted_value) - 1
                print("Inverse transformed predicted value:", predicted_value_inv)
                emrx[i, j] = predicted_value_inv

                        

            # Переходим к следующему элементу с учетом шага матрицы 3x3
        it.iternext()
    return emrx

# %%
array2 = process_matrix(full_matrix, empty_matrix, model)
plt.imshow(array2, cmap='rainbow', interpolation='nearest')
plt.colorbar()  # Добавление цветовой шкалы
plt.savefig(f'plots/predictions/prediction.png')
plt.show()

trx = empty_matrix.copy()
trx_abs = empty_matrix.copy()
it = np.nditer(full_matrix, flags=['multi_index'], op_flags=['readwrite'], order='C')
while not it.finished:
    # Получаем текущий индекс
    i, j = it.multi_index
    
    err = (abs(array2[i,j] - full_matrix[i, j]) * 100 +0.02)/(full_matrix[i, j]+0.02)
    abs_err = abs(array2[i,j] - full_matrix[i, j])
    trx[i, j] = err
    trx_abs[i, j] = abs_err

        # Переходим к следующему элементу с учетом шага матрицы 3x3
    it.iternext()
bad_color = 'gray'
pathi = f'plots/predictions/pr_mrx.txt'
np.savetxt(pathi, array2, fmt='%f', delimiter='\t')
plt.imshow(trx, cmap='rainbow', interpolation='nearest')
plt.clim(0, 100)
plt.colorbar()  # Добавление цветовой шкалы
plt.savefig(f'plots/rel_error/error.png')
plt.show()

plt.imshow(trx_abs, cmap='rainbow', interpolation='nearest')
plt.clim(0, 1)
plt.colorbar()  # Добавление цветовой шкалы
plt.savefig(f'plots/abs_error/abs_error.png')
plt.show()
full_path = f'plots/rel_error/errors.txt'
# Сохранение массива с числами с плавающей запятой в текстовый файл
np.savetxt(full_path, trx, fmt='%f', delimiter='\t')

full_path = f'plots/abs_error/abs_errors.txt'
# Сохранение массива с числами с плавающей запятой в текстовый файл
np.savetxt(full_path, trx_abs, fmt='%f', delimiter='\t')
# Out:
# Predicted value: 0.0002240897190404212
# Inverse transformed predicted value: 0.0002241148290171857
# Predicted value: 0.00033834157852652424
# Inverse transformed predicted value: 0.0003383988224943124
# Predicted value: 0.0016913539764118468
# Inverse transformed predicted value: 0.0016927851222929835
# Predicted value: 0.0018134266172182834
# Inverse transformed predicted value: 0.0018150718696308132
# Predicted value: 0.0024704550194201147
# Inverse transformed predicted value: 0.002473509107899785
# Predicted value: 0.0022507389110160148
# Inverse transformed predicted value: 0.0022532737252169976
# Predicted value: 0.003930994021857259
# Inverse transformed predicted value: 0.003938730512902167
# Predicted value: 0.004761386142263291
# Inverse transformed predicted value: 0.004772739553434047
# Predicted value: 0.004323506556602297
# Inverse transformed predicted value: 0.0043328663953214885
# Predicted value: 0.004708827593049136
# Inverse transformed predicted value: 0.004719931543721412
# Predicted value: 0.0054342280525361275
# Inverse transformed predicted value: 0.0054490202523902465
# Predicted value: 0.006067602491157231
# Inverse transformed predicted value: 0.006086047678302897
# Predicted value: 0.006620142728706924
# Inverse transformed predicted value: 0.006642104309767083
# Predicted value: 0.00688885356407809
# Inverse transformed predicted value: 0.006912636296346308
# Predicted value: 0.007464437108637867
# Inverse transformed predicted value: 0.007492365465887607
# Predicted value: 0.008570382433163104
# Inverse transformed predicted value: 0.008607213303714056
# Predicted value: 0.008719289940700037
# Inverse transformed predicted value: 0.008757413672634717
# Predicted value: 0.009637398590484736
# Inverse transformed predicted value: 0.009683987862465271
# Predicted value: 0.009448665925219757
# Inverse transformed predicted value: 0.009493445493710784
# Predicted value: 0.01035711908821213
# Inverse transformed predicted value: 0.010410939694444288
# Predicted value: 0.010364313002128256
# Inverse transformed predicted value: 0.010418208529910045
# Predicted value: 0.011505172212991965
# Inverse transformed predicted value: 0.01157161125989803
# Predicted value: 0.011499018440872533
# Inverse transformed predicted value: 0.011565386297873292
# Predicted value: 0.012435633168706772
# Inverse transformed predicted value: 0.012513277171829262
# Predicted value: 0.012345772298203883
# Inverse transformed predicted value: 0.012422295935234695
# Predicted value: 0.013056808125611497
# Inverse transformed predicted value: 0.013142420446935255
# Predicted value: 0.013242022166878087
# Inverse transformed predicted value: 0.013330086027618648
# Predicted value: 0.014011188879294423
# Inverse transformed predicted value: 0.014109805627220418
# Predicted value: 0.01427488928652565
# Inverse transformed predicted value: 0.014377262058576479
# Predicted value: 0.015070594937924398
# Inverse transformed predicted value: 0.015184728989042995
# Predicted value: 0.01531363014123599
# Inverse transformed predicted value: 0.015431484599987222
# Predicted value: 0.015694634293822673
# Inverse transformed predicted value: 0.01581844192377968
# Predicted value: 0.016040860242128474
# Inverse transformed predicted value: 0.01617020551846937
# Predicted value: 0.016488322424038415
# Inverse transformed predicted value: 0.0166250050010186
# Predicted value: 0.016878658006817204
# Inverse transformed predicted value: 0.01702190737233278
# Predicted value: 0.017336819498950717
# Inverse transformed predicted value: 0.017487974405778095
# Predicted value: 0.0177822754810677
# Inverse transformed predicted value: 0.017941321476294902
# Predicted value: 0.01809920545542809
# Inverse transformed predicted value: 0.01826398872197088
# Predicted value: 0.01848706946816492
# Inverse transformed predicted value: 0.018659013281615122
# Predicted value: 0.018832631267059696
# Inverse transformed predicted value: 0.019011083750253954
# Predicted value: 0.019153912453248267
# Inverse transformed predicted value: 0.019338525437590848
# Predicted value: 0.019481391562067074
# Inverse transformed predicted value: 0.019672392173692543
# Predicted value: 0.01996071161170221
# Inverse transformed predicted value: 0.020161258747736444
# Predicted value: 0.02024899717412154
# Inverse transformed predicted value: 0.02045539890611625
# Predicted value: 0.020526824988110093
# Inverse transformed predicted value: 0.020738949186120514
# Predicted value: 0.02088174638970486
# Inverse transformed predicted value: 0.021101295583069835
# Predicted value: 0.021162651147960787
# Inverse transformed predicted value: 0.021388168085699544
# Predicted value: 0.021573616457089884
# Inverse transformed predicted value: 0.021808009454147737
# Predicted value: 0.021941024536999976
# Inverse transformed predicted value: 0.022183498947651037
# Predicted value: 0.02220667057895298
# Inverse transformed predicted value: 0.022455074018120413
# Predicted value: 0.022483978089212542
# Inverse transformed predicted value: 0.022738647805801815
# Predicted value: 0.022827782409649444
# Inverse transformed predicted value: 0.023090330223098476
# Predicted value: 0.022972301088657332
# Inverse transformed predicted value: 0.023238196570595226
# Predicted value: 0.023356125577038256
# Inverse transformed predicted value: 0.023631015829888913
# Predicted value: 0.02356763418697483
# Inverse transformed predicted value: 0.02384754550127255
# Predicted value: 0.02388755485640104
# Inverse transformed predicted value: 0.024175147894013982
# Predicted value: 0.024202778473181752
# Inverse transformed predicted value: 0.024498042977754375
# Predicted value: 0.02460387137739417
# Inverse transformed predicted value: 0.024909044292517724
# Predicted value: 0.024686357024393146
# Inverse transformed predicted value: 0.02499358806492724
# Predicted value: 0.025125788324430687
# Inverse transformed predicted value: 0.025444101307421363
# Predicted value: 0.025210485127672655
# Inverse transformed predicted value: 0.025530956822845674
# Predicted value: 0.025272489921690067
# Inverse transformed predicted value: 0.02559454662999805
# Predicted value: 0.02561697709074906
# Inverse transformed predicted value: 0.025947911653332767
# Predicted value: 0.02572731336454126
# Inverse transformed predicted value: 0.026061117168231895
# Predicted value: 0.026063772336556212
# Inverse transformed predicted value: 0.026406402720892563
# Predicted value: 0.026145717503595733
# Inverse transformed predicted value: 0.02649051521127288
# Predicted value: 0.026472726454585427
# Inverse transformed predicted value: 0.026826241687642804
# Predicted value: 0.026741777077177176
# Inverse transformed predicted value: 0.027102547095666507
# Predicted value: 0.026948606002179076
# Inverse transformed predicted value: 0.027315003581664943
# Predicted value: 0.026977931865758364
# Inverse transformed predicted value: 0.027345130923065897
# Predicted value: 0.027338321345951044
# Inverse transformed predicted value: 0.02771544202488263
# Predicted value: 0.027478217667294302
# Inverse transformed predicted value: 0.02785922569177801
# Predicted value: 0.02761130953490465
# Inverse transformed predicted value: 0.027996034499633726
# Predicted value: 0.027731852463830364
# Inverse transformed predicted value: 0.02811995962155489
# Predicted value: 0.027924767567810704
# Inverse transformed predicted value: 0.02831831862307821
# Predicted value: 0.028121856146526625
# Inverse transformed predicted value: 0.028521008392226266
# Predicted value: 0.028235414803702952
# Inverse transformed predicted value: 0.028637812488749637
# Predicted value: 0.028546993056579595
# Inverse transformed predicted value: 0.028958363596991443
# Predicted value: 0.028480029770207693
# Inverse transformed predicted value: 0.028889463470340493
# Predicted value: 0.028667190741316517
# Inverse transformed predicted value: 0.029082049443213798
# Predicted value: 0.02881091490030485
# Inverse transformed predicted value: 0.029229964024494848
# Predicted value: 0.028944612746045095
# Inverse transformed predicted value: 0.029367579052667514
# Predicted value: 0.029037459305754965
# Inverse transformed predicted value: 0.029463156728020135
# Predicted value: 0.02929171939808839
# Inverse transformed predicted value: 0.029724941404591254
# Predicted value: 0.029259595295798135
# Inverse transformed predicted value: 0.02969186294655346
# Predicted value: 0.029370284846436334
# Inverse transformed predicted value: 0.029805845384374807
# Predicted value: 0.029486551942454753
# Inverse transformed predicted value: 0.02992558488022734
# Predicted value: 0.02954988876058451
# Inverse transformed predicted value: 0.029990819155528037
# Predicted value: 0.02964754559411631
# Inverse transformed predicted value: 0.030091409709091188
# Predicted value: 0.02980607738186336
# Inverse transformed predicted value: 0.03025472488679659
# Predicted value: 0.029822262654988663
# Inverse transformed predicted value: 0.030271399975852598
# Predicted value: 0.029878879347734255
# Inverse transformed predicted value: 0.03032973218642243
# Predicted value: 0.029962189819116247
# Inverse transformed predicted value: 0.03041557301776021
# Predicted value: 0.02993105095424653
# Inverse transformed predicted value: 0.0303834875460276
# Predicted value: 0.030060321256087263
# Inverse transformed predicted value: 0.03051669414011715
# Predicted value: 0.030110626237501492
# Inverse transformed predicted value: 0.030568535567192967
# Predicted value: 0.030206371844315072
# Inverse transformed predicted value: 0.030667212700869584
# Predicted value: 0.030103185057441806
# Inverse transformed predicted value: 0.030560866949687737
# Predicted value: 0.03022637452136223
# Inverse transformed predicted value: 0.03068782901045819
# Predicted value: 0.030090169213281115
# Inverse transformed predicted value: 0.030547453417339998
# Predicted value: 0.030259982627967474
# Inverse transformed predicted value: 0.030722469058982238
# Predicted value: 0.030264375247270436
# Inverse transformed predicted value: 0.030726996640339843
# Predicted value: 0.03027875959719495
# Inverse transformed predicted value: 0.030741823084770248
# Predicted value: 0.030112243770190616
# Inverse transformed predicted value: 0.030570202546835956
# Predicted value: 0.030283464675221694
# Inverse transformed predicted value: 0.030746672816882592
# Predicted value: 0.03010376524230196
# Inverse transformed predicted value: 0.030561464865673793
# Predicted value: 0.030111473144415868
# Inverse transformed predicted value: 0.030569408363181116
# Predicted value: 0.030017421998991267
# Inverse transformed predicted value: 0.030472486687753708
# Predicted value: 0.03012860159265074
# Inverse transformed predicted value: 0.030587060569121638
# Predicted value: 0.029838115489610573
# Inverse transformed predicted value: 0.03028773282743291
# Predicted value: 0.030036724547017002
# Inverse transformed predicted value: 0.0304923776243895
# Predicted value: 0.02970249222903476
# Inverse transformed predicted value: 0.03014801132073286
# Predicted value: 0.029846117544138906
# Inverse transformed predicted value: 0.03029597727903699
# Predicted value: 0.029589984402036862
# Inverse transformed predicted value: 0.03003211812606099
# Predicted value: 0.0297514975861759
# Inverse transformed predicted value: 0.03019849532891916
# Predicted value: 0.02934042131141723
# Inverse transformed predicted value: 0.02977509220065011
# Predicted value: 0.029633350513677215
# Inverse transformed predicted value: 0.030076787582452136
# Predicted value: 0.029157522923696888
# Inverse transformed predicted value: 0.029586765219447475
# Predicted value: 0.029301342477765502
# Inverse transformed predicted value: 0.029734850577426197
# Predicted value: 0.029202765024592736
# Inverse transformed predicted value: 0.029633346941480232
# Predicted value: 0.028695066448335638
# Inverse transformed predicted value: 0.029110736232753176
# Predicted value: 0.029014981216960223
# Inverse transformed predicted value: 0.029440016623845766
# Predicted value: 0.028549098667781436
# Inverse transformed predicted value: 0.028960530185529132
# Predicted value: 0.028708762419910272
# Inverse transformed predicted value: 0.02912483100066421
# Predicted value: 0.028248655031120506
# Inverse transformed predicted value: 0.028651431977479547
# Predicted value: 0.02820461092392179
# Inverse transformed predicted value: 0.02860612694125675
# Predicted value: 0.028134139316307483
# Inverse transformed predicted value: 0.02853364196798558
# Predicted value: 0.02781506185760918
# Inverse transformed predicted value: 0.028205512419475776
# Predicted value: 0.02775593696037504
# Inverse transformed predicted value: 0.028144721671359507
# Predicted value: 0.027377848022069884
# Inverse transformed predicted value: 0.027756065003142094
# Predicted value: 0.027463881003995994
# Inverse transformed predicted value: 0.02784448972577369
# Predicted value: 0.027034798982413122
# Inverse transformed predicted value: 0.02740355473965206
# Predicted value: 0.02696459764752035
# Inverse transformed predicted value: 0.02733143217021583
# Predicted value: 0.02675793090361367
# Inverse transformed predicted value: 0.02711913886595485
# Predicted value: 0.02651767281690809
# Inverse transformed predicted value: 0.026872394829144275
# Predicted value: 0.026325996473815394
# Inverse transformed predicted value: 0.026675586546029084
# Predicted value: 0.026057847669790135
# Inverse transformed predicted value: 0.026400321623004208
# Predicted value: 0.025891319080756148
# Inverse transformed predicted value: 0.026229410856819513
# Predicted value: 0.02556120365966308
# Inverse transformed predicted value: 0.02589069261385024
# Predicted value: 0.02553173345563664
# Inverse transformed predicted value: 0.02586045985131502
# Predicted value: 0.024860068344196407
# Inverse transformed predicted value: 0.02517165651970532
# Predicted value: 0.025085805118351345
# Inverse transformed predicted value: 0.02540310158425152
# Predicted value: 0.024513808402616633
# Inverse transformed predicted value: 0.024816742091680277
# Predicted value: 0.02446833975022855
# Inverse transformed predicted value: 0.024770146114808655
# Predicted value: 0.02406962715372174
# Inverse transformed predicted value: 0.02436163879294795
# Predicted value: 0.023918707392795113
# Inverse transformed predicted value: 0.024207054044558918
# Predicted value: 0.023548839835484614
# Inverse transformed predicted value: 0.023828303131454565
# Predicted value: 0.02330764197154167
# Inverse transformed predicted value: 0.02358138771062812
# Predicted value: 0.02296706807442206
# Inverse transformed predicted value: 0.023232841964556883
# Predicted value: 0.02283397496262296
# Inverse transformed predicted value: 0.023096665783781667
# Predicted value: 0.022299752559547414
# Inverse transformed predicted value: 0.022550250591022003
# Predicted value: 0.022230498350609196
# Inverse transformed predicted value: 0.02247943713441103
# Predicted value: 0.021750943680444834
# Inverse transformed predicted value: 0.021989219897563528
# Predicted value: 0.021563910984468748
# Inverse transformed predicted value: 0.021798092372612876
# Predicted value: 0.021096126805559834
# Inverse transformed predicted value: 0.021320223169502217
# Predicted value: 0.020970746165176024
# Inverse transformed predicted value: 0.021192177413281277
# Predicted value: 0.020389222106814486
# Inverse transformed predicted value: 0.020598502228836635
# Predicted value: 0.02035548424805711
# Inverse transformed predicted value: 0.020564070001558354
# Predicted value: 0.0197181421424375
# Inverse transformed predicted value: 0.01991382878332848
# Predicted value: 0.019716906830353764
# Inverse transformed predicted value: 0.019912568872229475
# Predicted value: 0.019020318202592534
# Inverse transformed predicted value: 0.019202356766998774
# Predicted value: 0.019012815642554415
# Inverse transformed predicted value: 0.01919471016881058
# Predicted value: 0.018302699918194776
# Inverse transformed predicted value: 0.018471220889894724
# Predicted value: 0.01827001199467304
# Inverse transformed predicted value: 0.018437929724629765
# Predicted value: 0.017569418956327354
# Inverse transformed predicted value: 0.017724669082971545
# Predicted value: 0.017473079660476287
# Inverse transformed predicted value: 0.017626626927713884
# Predicted value: 0.016724857345025157
# Inverse transformed predicted value: 0.01686550075795079
# Predicted value: 0.01674544478350981
# Inverse transformed predicted value: 0.016886435629391627
# Predicted value: 0.01580141346835262
# Inverse transformed predicted value: 0.015926915969761923
# Predicted value: 0.015774642251699333
# Inverse transformed predicted value: 0.015899718734243784
# Predicted value: 0.015041199166944352
# Inverse transformed predicted value: 0.015154887289859253
# Predicted value: 0.014690290368662318
# Inverse transformed predicted value: 0.01479872300253593
# Predicted value: 0.014390537431381745
# Inverse transformed predicted value: 0.014494579690770282
# Predicted value: 0.013850643361138282
# Inverse transformed predicted value: 0.013947007911580211
# Predicted value: 0.013345095521572148
# Inverse transformed predicted value: 0.01343453874205136
# Predicted value: 0.01303822359818696
# Inverse transformed predicted value: 0.01312359184879841
# Predicted value: 0.012353503861731951
# Inverse transformed predicted value: 0.012430123572792828
# Predicted value: 0.01204854564616653
# Inverse transformed predicted value: 0.012121421761892348
# Predicted value: 0.011374809957260368
# Inverse transformed predicted value: 0.011439749097931218
# Predicted value: 0.0108555352815074
# Inverse transformed predicted value: 0.010914670392011105
# Predicted value: 0.010362439443042604
# Inverse transformed predicted value: 0.010416315453468439
# Predicted value: 0.009569242367206243
# Inverse transformed predicted value: 0.009615173960222378
# Predicted value: 0.00959332898833054
# Inverse transformed predicted value: 0.009639492471273048
# Predicted value: 0.009131006230518324
# Inverse transformed predicted value: 0.009172821041441015
# Predicted value: 0.008208053306361762
# Inverse transformed predicted value: 0.008241831731022664
# Predicted value: 0.008191322300035608
# Inverse transformed predicted value: 0.008224962971673744
# Predicted value: 0.007512655636446652
# Inverse transformed predicted value: 0.007540946435770968
# Predicted value: 0.007299960506998104
# Inverse transformed predicted value: 0.007326670172310701
# Predicted value: 0.0068993354832400655
# Inverse transformed predicted value: 0.006923190728518325
# Predicted value: 0.006089191712590036
# Inverse transformed predicted value: 0.006107768527233937
# Predicted value: 0.005982435049872947
# Inverse transformed predicted value: 0.0060003655526259525
# Predicted value: 0.005024370624369112
# Inverse transformed predicted value: 0.005037013940487833
# Predicted value: 0.004060098322725025
# Inverse transformed predicted value: 0.004068351687964711
# Predicted value: 0.003248417054919628
# Inverse transformed predicted value: 0.003253698879241762
# Predicted value: 0.003368370238376883
# Inverse transformed predicted value: 0.0033740495723177943
# Predicted value: 0.003618294725811211
# Inverse transformed predicted value: 0.0036248486564729454
# Predicted value: 0.003087826891487566
# Inverse transformed predicted value: 0.003092599139637997
# Predicted value: 0.0013910260784086859
# Inverse transformed predicted value: 0.001391994003935304
# Predicted value: 0.001482222814729539
# Inverse transformed predicted value: 0.0014833218499037404
# Predicted value: 0.0005666068789196288
# Inverse transformed predicted value: 0.0005667674309191018
# Predicted value: -6.828596474406368e-05
# Inverse transformed predicted value: -6.828363331068399e-05
# Predicted value: -3.912948386641801e-06
# Inverse transformed predicted value: -3.912940731098935e-06
# Predicted value: 0.0011096526902747428
# Inverse transformed predicted value: 0.0011102685826089864
# Predicted value: 2.596690660539025e-05
# Inverse transformed predicted value: 2.596724374837045e-05
# Predicted value: 0.0013859726057035004
# Inverse transformed predicted value: 0.001386933509612831
# Predicted value: 0.002659025838283924
# Inverse transformed predicted value: 0.002662564182976501
# Predicted value: 0.002578116723952917
# Inverse transformed predicted value: 0.0025814429247044135
# Predicted value: 0.0038890235625785863
# Inverse transformed predicted value: 0.0038965956275114344
# Predicted value: 0.004312505134066669
# Inverse transformed predicted value: 0.004321817365869451
# Predicted value: 0.0044826901319083845
# Inverse transformed predicted value: 0.004492752417068369
# Predicted value: 0.0046473988948037
# Inverse transformed predicted value: 0.004658214801834593
# Predicted value: 0.005229552047012476
# Inverse transformed predicted value: 0.005243250022000101
# Predicted value: 0.005983181301189688
# Inverse transformed predicted value: 0.006001116282003505
# Predicted value: 0.006883611323928562
# Inverse transformed predicted value: 0.00690735783233265
# Predicted value: 0.007285723989980397
# Inverse transformed predicted value: 0.0073123294511097114
# Predicted value: 0.007665177490480346
# Inverse transformed predicted value: 0.007694630168702199
# Predicted value: 0.008144157098058713
# Inverse transformed predicted value: 0.00817741095906599
# Predicted value: 0.008517396203160388
# Inverse transformed predicted value: 0.00855377242575539
# Predicted value: 0.009188082043465329
# Inverse transformed predicted value: 0.009230422044402387
# Predicted value: 0.009672437390463529
# Inverse transformed predicted value: 0.009719366597568335
# Predicted value: 0.010237632177222622
# Inverse transformed predicted value: 0.010290216025022891
# Predicted value: 0.01060357346773344
# Inverse transformed predicted value: 0.01065999058422884
# Predicted value: 0.01104397868380147
# Inverse transformed predicted value: 0.011105188542309019
# Predicted value: 0.011405874832917107
# Inverse transformed predicted value: 0.011471169836009487
# Predicted value: 0.011903814945753766
# Inverse transformed predicted value: 0.011974947319548068
# Predicted value: 0.01237295641089986
# Inverse transformed predicted value: 0.012449818111104571
# Predicted value: 0.012988591453677145
# Inverse transformed predicted value: 0.01307330960009967
# Predicted value: 0.0134965286449642
# Inverse transformed predicted value: 0.01358801792022879
# Predicted value: 0.013957090475514633
# Inverse transformed predicted value: 0.014054945389417428
# Predicted value: 0.014290722032228587
# Inverse transformed predicted value: 0.014393322562954003
# Predicted value: 0.014693429405951974
# Inverse transformed predicted value: 0.014801908498568661
# Predicted value: 0.015047551776433465
# Inverse transformed predicted value: 0.015161336192912822
# Predicted value: 0.015553252905874615
# Inverse transformed predicted value: 0.015674834254522096
# Predicted value: 0.01599802062605704
# Inverse transformed predicted value: 0.016126674109442796
# Predicted value: 0.01640187119824077
# Inverse transformed predicted value: 0.016537120322083432
# Predicted value: 0.016823927438736064
# Inverse transformed predicted value: 0.016966246708775223
# Predicted value: 0.017160251041559604
# Inverse transformed predicted value: 0.017308333983605984
# Predicted value: 0.017540331191185032
# Inverse transformed predicted value: 0.017695066177361163
# Predicted value: 0.017959369844675166
# Inverse transformed predicted value: 0.01812160911030225
# Predicted value: 0.01837485980991005
# Inverse transformed predicted value: 0.018544716314588428
# Predicted value: 0.018739581082400036
# Inverse transformed predicted value: 0.018916268992074547
# Predicted value: 0.019173010968870585
# Inverse transformed predicted value: 0.019357993476248003
# Predicted value: 0.019459539780427804
# Inverse transformed predicted value: 0.019650110758680395
# Predicted value: 0.019790863083244403
# Inverse transformed predicted value: 0.01998800057338812
# Predicted value: 0.02016250900101113
# Inverse transformed predicted value: 0.020367145399421638
# Predicted value: 0.02039818544631089
# Inverse transformed predicted value: 0.02060765024069977
# Predicted value: 0.020738921364454654
# Inverse transformed predicted value: 0.020955467178966014
# Predicted value: 0.021062583651428213
# Inverse transformed predicted value: 0.021285965442398025
# Predicted value: 0.021481815467041088
# Inverse transformed predicted value: 0.02171421077271174
# Predicted value: 0.021808992769138058
# Inverse transformed predicted value: 0.02204854716236304
# Predicted value: 0.022076418539427323
# Inverse transformed predicted value: 0.02232190583230831
# Predicted value: 0.022370866787014165
# Inverse transformed predicted value: 0.022622971047837614
# Predicted value: 0.022661262580868424
# Inverse transformed predicted value: 0.02291997958025571
# Predicted value: 0.022965145293483147
# Inverse transformed predicted value: 0.02323087451384387
# Predicted value: 0.0232280764355437
# Inverse transformed predicted value: 0.023499949148771737
# Predicted value: 0.023540903155435444
# Inverse transformed predicted value: 0.023820177366033146
# Predicted value: 0.023875876536976648
# Inverse transformed predicted value: 0.024163187319330204
# Predicted value: 0.02412488570894311
# Inverse transformed predicted value: 0.024418245101108793
# Predicted value: 0.024406584637972628
# Inverse transformed predicted value: 0.024706863273438406
# Predicted value: 0.024645256143912775
# Inverse transformed predicted value: 0.024951460791711177
# Predicted value: 0.024935506709653055
# Inverse transformed predicted value: 0.025248996710957705
# Predicted value: 0.025125643387355012
# Inverse transformed predicted value: 0.02544395268256272
# Predicted value: 0.02537953064506837
# Inverse transformed predicted value: 0.02570433288785745
# Predicted value: 0.02552737837299901
# Inverse transformed predicted value: 0.02585599215396628
# Predicted value: 0.025780090883699813
# Inverse transformed predicted value: 0.026115271557555664
# Predicted value: 0.026045013702741926
# Inverse transformed predicted value: 0.026387148919627235
# Predicted value: 0.02623703780750475
# Inverse transformed predicted value: 0.026584258917368375
# Predicted value: 0.026487097911513047
# Inverse transformed predicted value: 0.026840998782787562
# Predicted value: 0.026794708279112456
# Inverse transformed predicted value: 0.027156914306843305
# Predicted value: 0.026940413674083175
# Inverse transformed predicted value: 0.02730658751457149
# Predicted value: 0.02695398664559434
# Inverse transformed predicted value: 0.027320531212245536
# Predicted value: 0.02727847847177145
# Inverse transformed predicted value: 0.027653942419167965
# Predicted value: 0.027384967692114515
# Inverse transformed predicted value: 0.0277633823132597
# Predicted value: 0.02766068878167971
# Inverse transformed predicted value: 0.028046797422812242
# Predicted value: 0.027834654541720738
# Inverse transformed predicted value: 0.028225657922634095
# Predicted value: 0.02794397493175893
# Inverse transformed predicted value: 0.028338070096964874
# Predicted value: 0.0281936504359237
# Inverse transformed predicted value: 0.02859485297793185
# Predicted value: 0.0281889702926037
# Inverse transformed predicted value: 0.02859003901786661
# Predicted value: 0.02841289360708288
# Inverse transformed predicted value: 0.028820390098170057
# Predicted value: 0.028552695719326948
# Inverse transformed predicted value: 0.028964231416251263
# Predicted value: 0.02874329949895582
# Inverse transformed predicted value: 0.029160374580082582
# Predicted value: 0.028818932598142055
# Inverse transformed predicted value: 0.029238216112432713
# Predicted value: 0.02904046059461507
# Inverse transformed predicted value: 0.029466246448960787
# Predicted value: 0.028993822259280932
# Inverse transformed predicted value: 0.029418234976539948
# Predicted value: 0.029186219584289574
# Inverse transformed predicted value: 0.029616311345335378
# Predicted value: 0.029278483900043284
# Inverse transformed predicted value: 0.029711312572334725
# Predicted value: 0.029412729421665063
# Inverse transformed predicted value: 0.029849555983682663
# Predicted value: 0.0294929778790447
# Inverse transformed predicted value: 0.029932203137992497
# Predicted value: 0.02966235931285155
# Inverse transformed predicted value: 0.030106669306531497
# Predicted value: 0.029593419032380552
# Inverse transformed predicted value: 0.030035655911704318
# Predicted value: 0.029738909597426755
# Inverse transformed predicted value: 0.03018552728347146
# Predicted value: 0.02978477006013236
# Inverse transformed predicted value: 0.03023277315177575
# Predicted value: 0.029868311237578382
# Inverse transformed predicted value: 0.03031884360585191
# Predicted value: 0.029926507198752006
# Inverse transformed predicted value: 0.030378805746031023
# Predicted value: 0.030043263217294225
# Inverse transformed predicted value: 0.03049911569629904
# Predicted value: 0.029991927232686066
# Inverse transformed predicted value: 0.030446215367413654
# Predicted value: 0.029978883936337297
# Inverse transformed predicted value: 0.030432775039708426
# Predicted value: 0.030003811403503278
# Inverse transformed predicted value: 0.0304584614390222
# Predicted value: 0.03001820325494009
# Inverse transformed predicted value: 0.03047329175082858
# Predicted value: 0.030007154487748267
# Inverse transformed predicted value: 0.030461906354227963
# Predicted value: 0.030041437715908614
# Inverse transformed predicted value: 0.030497234520452388
# Predicted value: 0.030093518824060084
# Inverse transformed predicted value: 0.030550905355979374
# Predicted value: 0.030067637871752595
# Inverse transformed predicted value: 0.030524234062288214
# Predicted value: 0.03009101170368922
# Inverse transformed predicted value: 0.030548321644050302
# Predicted value: 0.03008280811241093
# Inverse transformed predicted value: 0.03053986748150428
# Predicted value: 0.030037986794695826
# Inverse transformed predicted value: 0.030493678361822152
# Predicted value: 0.03006642881859989
# Inverse transformed predicted value: 0.030522988104467297
# Predicted value: 0.02998883683517306
# Inverse transformed predicted value: 0.030443030883913202
# Predicted value: 0.029953374683600487
# Inverse transformed predicted value: 0.030406489804881476
# Predicted value: 0.02996775003316543
# Inverse transformed predicted value: 0.03042130236483409
# Predicted value: 0.029879610348643837
# Inverse transformed predicted value: 0.030330485358669224
# Predicted value: 0.029842335530474884
# Inverse transformed predicted value: 0.030292080692941425
# Predicted value: 0.029806240341486046
# Inverse transformed predicted value: 0.030254892776731657
# Predicted value: 0.02970482199793878
# Inverse transformed predicted value: 0.030150411330331917
# Predicted value: 0.029558217396470354
# Inverse transformed predicted value: 0.0299993976097499
# Predicted value: 0.029540132632746463
# Inverse transformed predicted value: 0.02998077048244241
# Predicted value: 0.029364871366624357
# Inverse transformed predicted value: 0.029800270566310294
# Predicted value: 0.02936526942698947
# Inverse transformed predicted value: 0.02980068048906359
# Predicted value: 0.029224995672620935
# Inverse transformed predicted value: 0.029656236612439324
# Predicted value: 0.02912430781339026
# Inverse transformed predicted value: 0.02955256794940686
# Predicted value: 0.029036031042551258
# Inverse transformed predicted value: 0.029461686384723684
# Predicted value: 0.028844108401017365
# Inverse transformed predicted value: 0.029264128337052497
# Predicted value: 0.02883730383814509
# Inverse transformed predicted value: 0.029257124668407464
# Predicted value: 0.028544819640728747
# Inverse transformed predicted value: 0.028956127245004515
# Predicted value: 0.02849306231269111
# Inverse transformed predicted value: 0.028902872603361107
# Predicted value: 0.028269039965152842
# Inverse transformed predicted value: 0.02867240118278991
# Predicted value: 0.028165616957039674
# Inverse transformed predicted value: 0.02856601829001071
# Predicted value: 0.027989415768161052
# Inverse transformed predicted value: 0.028384799700682306
# Predicted value: 0.02780593379043239
# Inverse transformed predicted value: 0.02819612693332263
# Predicted value: 0.027644425233802394
# Inverse transformed predicted value: 0.0280300778704623
# Predicted value: 0.027410694685158887
# Inverse transformed predicted value: 0.0277898239147778
# Predicted value: 0.02738448436480212
# Inverse transformed predicted value: 0.02776288556726647
# Predicted value: 0.027004747727687572
# Inverse transformed predicted value: 0.02737268043763086
# Predicted value: 0.026889105811051195
# Inverse transformed predicted value: 0.027253879961054883
# Predicted value: 0.026684788444754304
# Inverse transformed predicted value: 0.027044015593980397
# Predicted value: 0.026476310649513835
# Inverse transformed predicted value: 0.02682992203964618
# Predicted value: 0.026259539725060677
# Inverse transformed predicted value: 0.026607359291627164
# Predicted value: 0.02605587473567539
# Inverse transformed predicted value: 0.02639829660479176
# Predicted value: 0.025858014134200857
# Inverse transformed predicted value: 0.026195232910287913
# Predicted value: 0.025616071961621856
# Inverse transformed predicted value: 0.02594698303841514
# Predicted value: 0.025326219201588174
# Inverse transformed predicted value: 0.025649652566843706
# Predicted value: 0.025062245371145764
# Inverse transformed predicted value: 0.02537894363097304
# Predicted value: 0.024883925990934586
# Inverse transformed predicted value: 0.02519611499469221
# Predicted value: 0.02463287875775677
# Inverse transformed predicted value: 0.024938774650200557
# Predicted value: 0.024404390230984063
# Inverse transformed predicted value: 0.024704614652003798
# Predicted value: 0.02410536235743166
# Inverse transformed predicted value: 0.024398245218848036
# Predicted value: 0.023842413738520918
# Inverse transformed predicted value: 0.024128916526408695
# Predicted value: 0.02356869293339514
# Inverse transformed predicted value: 0.023848629496770135
# Predicted value: 0.02325240381810545
# Inverse transformed predicted value: 0.023524848526453646
# Predicted value: 0.022994840892124557
# Inverse transformed predicted value: 0.023261260418372398
# Predicted value: 0.02272702507229951
# Inverse transformed predicted value: 0.02298725155860981
# Predicted value: 0.022405719264270374
# Inverse transformed predicted value: 0.022658612612772577
# Predicted value: 0.022125027444189982
# Inverse transformed predicted value: 0.022371600988269513
# Predicted value: 0.021822527520043877
# Inverse transformed predicted value: 0.02206238042847719
# Predicted value: 0.02149851167973793
# Inverse transformed predicted value: 0.02173126967289929
# Predicted value: 0.02116091404218423
# Inverse transformed predicted value: 0.02138639382795371
# Predicted value: 0.020883203749463064
# Inverse transformed predicted value: 0.02110278369609153
# Predicted value: 0.020510178601170992
# Inverse transformed predicted value: 0.020721957712032335
# Predicted value: 0.020240624773350646
# Inverse transformed predicted value: 0.020446855280313203
# Predicted value: 0.019833935340784592
# Inverse transformed predicted value: 0.02003193470540099
# Predicted value: 0.019593181397567605
# Inverse transformed predicted value: 0.019786387554321827
# Predicted value: 0.019155807505512712
# Inverse transformed predicted value: 0.01934045713920196
# Predicted value: 0.01889892215308464
# Inverse transformed predicted value: 0.019078637136927146
# Predicted value: 0.01843709711442898
# Inverse transformed predicted value: 0.018608109764961966
# Predicted value: 0.018163744727416997
# Inverse transformed predicted value: 0.01832970885923757
# Predicted value: 0.017681520013638874
# Inverse transformed predicted value: 0.0178387634893602
# Predicted value: 0.017402137720409883
# Inverse transformed predicted value: 0.017554437081210628
# Predicted value: 0.01688291908408246
# Inverse transformed predicted value: 0.017026240990493546
# Predicted value: 0.01664083409173145
# Inverse transformed predicted value: 0.016780063999802364
# Predicted value: 0.016108726562151787
# Inverse transformed predicted value: 0.016239171591045487
# Predicted value: 0.01582546354961778
# Inverse transformed predicted value: 0.01595134938846221
# Predicted value: 0.015229522035724585
# Inverse transformed predicted value: 0.015346082173109288
# Predicted value: 0.014796870618511093
# Inverse transformed predicted value: 0.014906886267911368
# Predicted value: 0.014405987534473752
# Inverse transformed predicted value: 0.01451025385769622
# Predicted value: 0.013908571145066162
# Inverse transformed predicted value: 0.014005745316016283
# Predicted value: 0.013557959249510532
# Inverse transformed predicted value: 0.013650285157468023
# Predicted value: 0.01308998219951718
# Inverse transformed predicted value: 0.013176031065965654
# Predicted value: 0.0126887879921469
# Inverse transformed predicted value: 0.012769632239134188
# Predicted value: 0.012237470280297202
# Inverse transformed predicted value: 0.012312654494912811
# Predicted value: 0.011802947574096834
# Inverse transformed predicted value: 0.011872877214287536
# Predicted value: 0.011294232393765924
# Inverse transformed predicted value: 0.011358253030749
# Predicted value: 0.010825216759030809
# Inverse transformed predicted value: 0.010884021417473022
# Predicted value: 0.010380739043966969
# Inverse transformed predicted value: 0.010434805837991501
# Predicted value: 0.009769491709221256
# Inverse transformed predicted value: 0.009817368978530139
# Predicted value: 0.00923021356334175
# Inverse transformed predicted value: 0.009272943351726015
# Predicted value: 0.008593912268906934
# Inverse transformed predicted value: 0.008630945944984703
# Predicted value: 0.008279231613187221
# Inverse transformed predicted value: 0.00831359923159014
# Predicted value: 0.007874099017271874
# Inverse transformed predicted value: 0.007905181262938932
# Predicted value: 0.0076965809601006185
# Inverse transformed predicted value: 0.007726275773295654
# Predicted value: 0.006969321027781916
# Inverse transformed predicted value: 0.006993663262333749
# Predicted value: 0.006462814813630757
# Inverse transformed predicted value: 0.006483743863854308
# Predicted value: 0.006073690313996849
# Inverse transformed predicted value: 0.006092172570566268
# Predicted value: 0.005349708520725471
# Inverse transformed predicted value: 0.005364043763076198
# Predicted value: 0.0044355313909818506
# Inverse transformed predicted value: 0.0044453829205461926
# Predicted value: 0.003468896498588947
# Inverse transformed predicted value: 0.003474920083097688
# Predicted value: 0.0032883664277960634
# Inverse transformed predicted value: 0.00329377903593131
# Predicted value: 0.0031232629005444323
# Inverse transformed predicted value: 0.0031281453678704274
# Predicted value: 0.002427955801749704
# Inverse transformed predicted value: 0.0024309056733402556
# Predicted value: 0.0016227744088155305
# Inverse transformed predicted value: 0.0016240918197303333
# Predicted value: 0.0007830048014056956
# Inverse transformed predicted value: 0.0007833114296904586
# Predicted value: 0.0005190693807435309
# Inverse transformed predicted value: 0.0005192041205666076
# Predicted value: -0.00020126392723796016
# Inverse transformed predicted value: -0.00020124367501250795
# Predicted value: -2.292683006999141e-05
# Inverse transformed predicted value: -2.2926567252223862e-05
# Predicted value: 0.000609348065836457
# Inverse transformed predicted value: 0.0006095337560838576
# Predicted value: 0.0007409391726014292
# Inverse transformed predicted value: 0.0007412137358375759
# Predicted value: 0.001479733389487592
# Inverse transformed predicted value: 0.0014808287351462113
# Predicted value: 0.0025595102958959615
# Inverse transformed predicted value: 0.0025627886387606935
# Predicted value: 0.0025825053487551486
# Inverse transformed predicted value: 0.002585842888146006
# Predicted value: 0.0035618965082448995
# Inverse transformed predicted value: 0.0035682476000176155
# Predicted value: 0.004135255938081173
# Inverse transformed predicted value: 0.004143817906827163
# Predicted value: 0.005108991059159962
# Inverse transformed predicted value: 0.0051220642080329615
# Predicted value: 0.004747015194652704
# Inverse transformed predicted value: 0.004758300120787817
# Predicted value: 0.005587438590509919
# Inverse transformed predicted value: 0.005603077438979254
# Predicted value: 0.005988504333572564
# Inverse transformed predicted value: 0.0060064712727749825
# Predicted value: 0.006624252305982736
# Inverse transformed predicted value: 0.006646241191784252
# Predicted value: 0.00717746297937083
# Inverse transformed predicted value: 0.00720328270318582
# Predicted value: 0.007701821308501167
# Inverse transformed predicted value: 0.0077315566239097855
# Predicted value: 0.008311896908480776
# Inverse transformed predicted value: 0.008346536631009593
# Predicted value: 0.008771245254820315
# Inverse transformed predicted value: 0.008809825342453781
# Predicted value: 0.009168061052832854
# Inverse transformed predicted value: 0.009210216453845232
# Predicted value: 0.009641866785159436
# Inverse transformed predicted value: 0.009688499337161982
# Predicted value: 0.010112763415008885
# Inverse transformed predicted value: 0.010164070212270948
# Predicted value: 0.010595249859534306
# Inverse transformed predicted value: 0.010651578281455132
# Predicted value: 0.011087695722153512
# Inverse transformed predicted value: 0.011149392032830274
# Predicted value: 0.01152978054938103
# Inverse transformed predicted value: 0.011596504660680962
# Predicted value: 0.011959058206912232
# Inverse transformed predicted value: 0.012030853660058849
# Predicted value: 0.012388398204848272
# Inverse transformed predicted value: 0.012465452273288324
# Predicted value: 0.012839406935881925
# Inverse transformed predicted value: 0.012922186019845183
# Predicted value: 0.01333454242899279
# Inverse transformed predicted value: 0.013423843929972534
# Predicted value: 0.013822052456589518
# Inverse transformed predicted value: 0.013918018663875875
# Predicted value: 0.014200507346458835
# Inverse transformed predicted value: 0.014301813515904094
# Predicted value: 0.014684618454111842
# Inverse transformed predicted value: 0.014792967167216453
# Predicted value: 0.015256904330954058
# Inverse transformed predicted value: 0.015373885059943193
# Predicted value: 0.015580346287379143
# Inverse transformed predicted value: 0.015702352693073296
# Predicted value: 0.016048771492705782
# Inverse transformed predicted value: 0.016178244727394375
# Predicted value: 0.016348323526244712
# Inverse transformed predicted value: 0.01648268858315216
# Predicted value: 0.01679999597013193
# Inverse transformed predicted value: 0.016941909504184283
# Predicted value: 0.017194935938960043
# Inverse transformed predicted value: 0.017343619830734402
# Predicted value: 0.017712986667675068
# Inverse transformed predicted value: 0.017870791973507494
# Predicted value: 0.017974927617387948
# Inverse transformed predicted value: 0.018137448938106537
# Predicted value: 0.01843132607223197
# Inverse transformed predicted value: 0.0186022313515406
# Predicted value: 0.018699991985840825
# Inverse transformed predicted value: 0.01887593181597702
# Predicted value: 0.019109666452777674
# Inverse transformed predicted value: 0.019293424782483637
# Predicted value: 0.019460404266055775
# Inverse transformed predicted value: 0.019650992231927678
# Predicted value: 0.019875271554838037
# Inverse transformed predicted value: 0.02007409983526265
# Predicted value: 0.02014648172530542
# Inverse transformed predicted value: 0.020350791824913284
# Predicted value: 0.02052111717398475
# Inverse transformed predicted value: 0.020733123014555543
# Predicted value: 0.020790509271819246
# Inverse transformed predicted value: 0.02100813749359398
# Predicted value: 0.021174890283646164
# Inverse transformed predicted value: 0.021400669070576805
# Predicted value: 0.02153947002420864
# Inverse transformed predicted value: 0.021773118951231796
# Predicted value: 0.02198977132843538
# Inverse transformed predicted value: 0.022233328327984303
# Predicted value: 0.022096283853670684
# Inverse transformed predicted value: 0.02234221477994658
# Predicted value: 0.02245279126850619
# Inverse transformed predicted value: 0.02270675233632491
# Predicted value: 0.022709713560971068
# Inverse transformed predicted value: 0.022969542256503495
# Predicted value: 0.023036263348103603
# Inverse transformed predicted value: 0.023303647290765284
# Predicted value: 0.023303485136921154
# Inverse transformed predicted value: 0.023577132860922
# Predicted value: 0.02362043284279025
# Inverse transformed predicted value: 0.023901604702549095
# Predicted value: 0.023906285746988942
# Inverse transformed predicted value: 0.024194331786317136
# Predicted value: 0.024296200684830183
# Inverse transformed predicted value: 0.024593758321658887
# Predicted value: 0.024456064693140434
# Inverse transformed predicted value: 0.024757567079967346
# Predicted value: 0.024799902868608115
# Inverse transformed predicted value: 0.025109978434895375
# Predicted value: 0.024994358052708776
# Inverse transformed predicted value: 0.025309335766880547
# Predicted value: 0.02516813355373415
# Inverse transformed predicted value: 0.02548752489241335
# Predicted value: 0.02543939942893303
# Inverse transformed predicted value: 0.02576574239711027
# Predicted value: 0.025629146879282416
# Inverse transformed predicted value: 0.025960397298437465
# Predicted value: 0.025852295296999728
# Inverse transformed predicted value: 0.026189364283595307
# Predicted value: 0.02606473255923447
# Inverse transformed predicted value: 0.026407388300070833
# Predicted value: 0.02628999254716291
# Inverse transformed predicted value: 0.026638622858938144
# Predicted value: 0.026528898302558446
# Inverse transformed predicted value: 0.0268839220351762
# Predicted value: 0.02683326340388703
# Inverse transformed predicted value: 0.027196517233280426
# Predicted value: 0.027010854329773792
# Inverse transformed predicted value: 0.02737895421294012
# Predicted value: 0.027135184198186835
# Inverse transformed predicted value: 0.02750669604402578
# Predicted value: 0.027426716663967454
# Inverse transformed predicted value: 0.02780629127347578
# Predicted value: 0.027488373776350272
# Inverse transformed predicted value: 0.027869664795178606
# Predicted value: 0.027692641797102624
# Inverse transformed predicted value: 0.028079647142806863
# Predicted value: 0.027881728270358508
# Inverse transformed predicted value: 0.02827406147749234
# Predicted value: 0.027991058402903946
# Inverse transformed predicted value: 0.02838648896267082
# Predicted value: 0.02817872702485147
# Inverse transformed predicted value: 0.028579502948651747
# Predicted value: 0.028388001071789404
# Inverse transformed predicted value: 0.02879478046904449
# Predicted value: 0.02849146126004598
# Inverse transformed predicted value: 0.02890122527701422
# Predicted value: 0.028615307873906204
# Inverse transformed predicted value: 0.029028659100722276
# Predicted value: 0.028779952062677694
# Inverse transformed predicted value: 0.029198096637592652
# Predicted value: 0.028849918631522087
# Inverse transformed predicted value: 0.02927010861626167
# Predicted value: 0.029003045554190976
# Inverse transformed predicted value: 0.02942772964829299
# Predicted value: 0.029163239352556047
# Inverse transformed predicted value: 0.02959265079576756
# Predicted value: 0.02924891320049028
# Inverse transformed predicted value: 0.029680863738683172
# Predicted value: 0.029353508409030837
# Inverse transformed predicted value: 0.029788569055988035
# Predicted value: 0.02945776948376988
# Inverse transformed predicted value: 0.029895941516238533
# Predicted value: 0.029500176733336048
# Inverse transformed predicted value: 0.02993961749654006
# Predicted value: 0.029611429886927
# Inverse transformed predicted value: 0.030054207901148766
# Predicted value: 0.0297210827300205
# Inverse transformed predicted value: 0.03016716246636686
# Predicted value: 0.029775639271747423
# Inverse transformed predicted value: 0.03022336635728262
# Predicted value: 0.029879835517704123
# Inverse transformed predicted value: 0.030330717357242465
# Predicted value: 0.029933365487295305
# Inverse transformed predicted value: 0.030385872405422232
# Predicted value: 0.029933283152558943
# Inverse transformed predicted value: 0.030385787568876665
# Predicted value: 0.030018542118114055
# Inverse transformed predicted value: 0.03047364094033811
# Predicted value: 0.030063580644991816
# Inverse transformed predicted value: 0.03052005300026983
# Predicted value: 0.030011440376028986
# Inverse transformed predicted value: 0.030466322808300417
# Predicted value: 0.03004758421934639
# Inverse transformed predicted value: 0.030503568494712807
# Predicted value: 0.030131980147189097
# Inverse transformed predicted value: 0.03059054246959425
# Predicted value: 0.02999713727672315
# Inverse transformed predicted value: 0.030451584051559122
# Predicted value: 0.030065113507362184
# Inverse transformed predicted value: 0.030521632646891783
# ...
# Predicted value: 0.5713522887446061
# Inverse transformed predicted value: 0.7706598765954702
# Predicted value: 0.4993903668284929
# Inverse transformed predicted value: 0.6477164618364672
# Predicted value: 0.38211798702627675
# Inverse transformed predicted value: 0.46538497134871415
# Predicted value: 0.2164850221049619
# Inverse transformed predicted value: 0.24170448709507197
# Predicted value: -8.886446835276729e-05
# Inverse transformed predicted value: -8.886052002288203e-05
# Predicted value: -0.00017290701748606807
# Inverse transformed predicted value: -0.00017289206992920914
# Predicted value: 0.21671638498423818
# Inverse transformed predicted value: 0.241991804656444
# Predicted value: 0.3807174029077487
# Inverse transformed predicted value: 0.46333401303540356
# Predicted value: 0.49971395298030075
# Inverse transformed predicted value: 0.6482497263394744
# Predicted value: 0.5703646718372966
# Inverse transformed predicted value: 0.7689120062194883
# Predicted value: 0.5922326096231245
# Inverse transformed predicted value: 0.8080205166732846
# Predicted value: 0.5698152394509179
# Inverse transformed predicted value: 0.7679403756217191
# Predicted value: 0.4997615233282886
# Inverse transformed predicted value: 0.6483281360175004
# Predicted value: 0.38123528496566905
# Inverse transformed predicted value: 0.4640920437338061
# Predicted value: 0.2167573985677791
# Inverse transformed predicted value: 0.24204274423568162
# Predicted value: -8.05198180842126e-05
# Inverse transformed predicted value: -8.051657645069543e-05
# Predicted value: 0.00019139657138111943
# Inverse transformed predicted value: 0.0001914148888735312
# Predicted value: 0.2156382859718633
# Inverse transformed predicted value: 0.2406535360411246
# Predicted value: 0.38233380998622124
# Inverse transformed predicted value: 0.46570126920163046
# Predicted value: 0.5011397281366499
# Inverse transformed predicted value: 0.6506014359569359
# Predicted value: 0.5719303375724394
# Inverse transformed predicted value: 0.7716837003431778
# Predicted value: 0.5974177783159575
# Inverse transformed predicted value: 0.8174197553123379
# Predicted value: 0.5710189198929356
# Inverse transformed predicted value: 0.770069692125736
# Predicted value: 0.4976952759859614
# Inverse transformed predicted value: 0.6449257986329489
# Predicted value: 0.38226257472592806
# Inverse transformed predicted value: 0.46559686330894157
# Predicted value: 0.21674290718851807
# Inverse transformed predicted value: 0.2420247454536304
# Predicted value: -0.0005260049331354821
# Inverse transformed predicted value: -0.0005258666167934356
# Predicted value: -0.0002580224502253259
# Inverse transformed predicted value: -0.00025798916529573557
# Predicted value: 0.2165692807209325
# Inverse transformed predicted value: 0.24180911580447217
# Predicted value: 0.38199662800411716
# Inverse transformed predicted value: 0.46520714445217126
# Predicted value: 0.5003771313602101
# Inverse transformed predicted value: 0.6493431724575114
# Predicted value: 0.5720772071433657
# Inverse transformed predicted value: 0.771943925877203
# Predicted value: 0.5921837763962685
# Inverse transformed predicted value: 0.8079322273529772
# Predicted value: 0.5714816454481024
# Inverse transformed predicted value: 0.7708889381351232
# Predicted value: 0.49894619084216174
# Inverse transformed predicted value: 0.6469847482686648
# Predicted value: 0.38323557884109505
# Inverse transformed predicted value: 0.46702358908057917
# Predicted value: 0.21655074181376222
# Inverse transformed predicted value: 0.24178609423394914
# Predicted value: 0.0005582035553288733
# Inverse transformed predicted value: 0.0005583593799260989
# Predicted value: -0.0001924573409723962
# Inverse transformed predicted value: -0.00019243882224639908
# Predicted value: 0.21611530194400075
# Inverse transformed predicted value: 0.24124548876793317
# Predicted value: 0.38296055493788117
# Inverse transformed predicted value: 0.46662017800339073
# Predicted value: 0.5013120973478635
# Inverse transformed predicted value: 0.650885973346518
# Predicted value: 0.5718252696917716
# Inverse transformed predicted value: 0.7714975630702647
# Predicted value: 0.5867017564933121
# Inverse transformed predicted value: 0.7980482238047917
# Predicted value: 0.572749755394625
# Inverse transformed predicted value: 0.7731360444995936
# Predicted value: 0.4977167126835411
# Inverse transformed predicted value: 0.644961060787786
# Predicted value: 0.38203251715344777
# Inverse transformed predicted value: 0.4652597304338062
# Predicted value: 0.21696673008023026
# Inverse transformed predicted value: 0.24230277013671953
# Predicted value: 0.00021178135989430302
# Inverse transformed predicted value: 0.00021180378714968917
# Predicted value: 0.00034016976474049443
# Inverse transformed predicted value: 0.0003402276290358497
# Predicted value: 0.2161507965099645
# Inverse transformed predicted value: 0.24128954701972094
# Predicted value: 0.38330235485568664
# Inverse transformed predicted value: 0.46712155433999825
# Predicted value: 0.5035607112711205
# Inverse transformed predicted value: 0.6546023553201021
# Predicted value: 0.5650237331067274
# Inverse transformed predicted value: 0.7594895403793411
# Predicted value: 0.5912012132471318
# Inverse transformed predicted value: 0.8061566922007952
# Predicted value: 0.5745830170966428
# Inverse transformed predicted value: 0.7763896483448645
# Predicted value: 0.49742185810123374
# Inverse transformed predicted value: 0.6444761079800878
# Predicted value: 0.3832067611117509
# Inverse transformed predicted value: 0.466981313400995
# Predicted value: 0.2162549146485162
# Inverse transformed predicted value: 0.24141879450514736
# Predicted value: -0.0005618869292902673
# Inverse transformed predicted value: -0.0005617291003916502
# Predicted value: -0.00016718497158763057
# Inverse transformed predicted value: -0.00016717099695906512
# Predicted value: 0.2171500981819463
# Inverse transformed predicted value: 0.24253058972422026
# Predicted value: 0.38277770320542004
# Inverse transformed predicted value: 0.46635202847952995
# Predicted value: 0.502821702366191
# Inverse transformed predicted value: 0.6533800411515598
# Predicted value: 0.5684007608044794
# Inverse transformed predicted value: 0.7654414294818495
# Predicted value: 0.5857511786159648
# Inverse transformed predicted value: 0.7963398510401576
# Predicted value: 0.5735539210929801
# Inverse transformed predicted value: 0.7745625131668104
# Predicted value: 0.500355832462219
# Inverse transformed predicted value: 0.649308043639633
# Predicted value: 0.3816119605237418
# Inverse transformed predicted value: 0.46464363530045816
# Predicted value: 0.2161373388987613
# Inverse transformed predicted value: 0.24127284234000945
# Predicted value: -0.00012069334866282588
# Inverse transformed predicted value: -0.00012068606551363104
# Predicted value: -0.00019126524807688838
# Inverse transformed predicted value: -0.00019124695804539904
# Predicted value: 0.21606749901889089
# Inverse transformed predicted value: 0.2411861550209653
# Predicted value: 0.3827819284758789
# Inverse transformed predicted value: 0.4663582242265276
# Predicted value: 0.5041243226903589
# Inverse transformed predicted value: 0.6555351709499369
# Predicted value: 0.5675247261244749
# Inverse transformed predicted value: 0.7638955187986578
# Predicted value: 0.5838583372612902
# Inverse transformed predicted value: 0.7929428806603025
# Predicted value: 0.5702626262620925
# Inverse transformed predicted value: 0.7687315057861202
# Predicted value: 0.5028454967061862
# Inverse transformed predicted value: 0.6534193827064516
# Predicted value: 0.38186975207213436
# Inverse transformed predicted value: 0.46502125672275985
# Predicted value: 0.21590057807384255
# Inverse transformed predicted value: 0.24097899234536402
# Predicted value: 0.00032359967349293584
# Inverse transformed predicted value: 0.0003236520375153873
# Predicted value: -0.00036173453213450557
# Inverse transformed predicted value: -0.00036166911408686
# Predicted value: 0.21584401140330556
# Inverse transformed predicted value: 0.24090879628095818
# Predicted value: 0.3853987736399631
# Inverse transformed predicted value: 0.4702004817583214
# Predicted value: 0.50394243333335
# Inverse transformed predicted value: 0.6552340741061728
# Predicted value: 0.5734796112699314
# Inverse transformed predicted value: 0.7744306506398695
# Predicted value: 0.5826112929948977
# Inverse transformed predicted value: 0.790708395061807
# Predicted value: 0.5607313323453127
# Inverse transformed predicted value: 0.7519532920067342
# Predicted value: 0.5047150929033251
# Inverse transformed predicted value: 0.6565135007710565
# Predicted value: 0.3856885055276962
# Inverse transformed predicted value: 0.47062650743287837
# Predicted value: 0.21655352646826032
# Inverse transformed predicted value: 0.24178955218399678
# Predicted value: 0.00043398747561695927
# Inverse transformed predicted value: 0.0004340816618062515
# Predicted value: 5.0729609711197554e-05
# Inverse transformed predicted value: 5.073089647966711e-05
# Predicted value: 0.2156595946323705
# Inverse transformed predicted value: 0.2406799729877982
# Predicted value: 0.3875690565107561
# Inverse transformed predicted value: 0.4733946976027157
# Predicted value: 0.5013525336978546
# Inverse transformed predicted value: 0.6509527304992304
# Predicted value: 0.5724655512356094
# Inverse transformed predicted value: 0.7726321834643386
# Predicted value: 0.5821187569856647
# Inverse transformed predicted value: 0.7898266238650622
# Predicted value: 0.5650366009685968
# Inverse transformed predicted value: 0.7595121813933778
# Predicted value: 0.5018810234653301
# Inverse transformed predicted value: 0.6518254727212387
# Predicted value: 0.38785229322161285
# Inverse transformed predicted value: 0.47381207617633536
# Predicted value: 0.21765729086814645
# Inverse transformed predicted value: 0.24316095199576226
# Predicted value: -0.00021617998959300166
# Inverse transformed predicted value: -0.0002161566243827906
# Predicted value: 0.0003396929275822913
# Inverse transformed predicted value: 0.00033975062975821757
# Predicted value: 0.21639502654193166
# Inverse transformed predicted value: 0.24159274422889498
# Predicted value: 0.38751392795506945
# Inverse transformed predicted value: 0.4733134737199787
# Predicted value: 0.5090252493298522
# Inverse transformed predicted value: 0.6636687421095793
# Predicted value: 0.5675182761817723
# Inverse transformed predicted value: 0.7638841418103186
# Predicted value: 0.584004981663611
# Inverse transformed predicted value: 0.793205824976617
# Predicted value: 0.5639430862864856
# Inverse transformed predicted value: 0.7575891805960964
# Predicted value: 0.5035142372935297
# Inverse transformed predicted value: 0.6545254611541222
# Predicted value: 0.38610585779019857
# Inverse transformed predicted value: 0.4712404048298744
# Predicted value: 0.21677687438545945
# Inverse transformed predicted value: 0.24206693426927917
# Predicted value: -0.00010245432736155635
# Inverse transformed predicted value: -0.00010244907909617851
# Predicted value: 0.00023645768283131474
# Inverse transformed predicted value: 0.0002364856411527505
# Predicted value: 0.21599946031687978
# Inverse transformed predicted value: 0.2411017091988481
# Predicted value: 0.3870168543851378
# Inverse transformed predicted value: 0.4725813105165324
# Predicted value: 0.5038638748026187
# Inverse transformed predicted value: 0.6551040464567524
# Predicted value: 0.5610894509211448
# Inverse transformed predicted value: 0.7525808113810579
# Predicted value: 0.5905070572091518
# Inverse transformed predicted value: 0.8049033726773496
# Predicted value: 0.5590138607841482
# Inverse transformed predicted value: 0.7489469444484287
# Predicted value: 0.5052286802542767
# Inverse transformed predicted value: 0.6573644836600514
# Predicted value: 0.38860423549363077
# Inverse transformed predicted value: 0.4749207145412113
# Predicted value: 0.21615044633267644
# Inverse transformed predicted value: 0.2412891123483898
# Predicted value: 1.5562869293717085e-05
# Inverse transformed predicted value: 1.556299039573439e-05
# Predicted value: -0.00029378523709056026
# Inverse transformed predicted value: -0.00029374208643362376
# Predicted value: 0.2165508926880193
# Inverse transformed predicted value: 0.2417862815875178
# Predicted value: 0.3889475113244316
# Inverse transformed predicted value: 0.47542710608587746
# Predicted value: 0.5060737960054666
# Inverse transformed predicted value: 0.6587657405193765
# Predicted value: 0.5629258624514932
# Inverse transformed predicted value: 0.7558022280089378
# Predicted value: 0.5850530680331758
# Inverse transformed predicted value: 0.7950862448086622
# Predicted value: 0.5653528743897596
# Inverse transformed predicted value: 0.7600687563408566
# Predicted value: 0.5059739385890225
# Inverse transformed predicted value: 0.6586001087279612
# Predicted value: 0.3852646460484266
# Inverse transformed predicted value: 0.4700033005326443
# Predicted value: 0.21552234189925912
# Inverse transformed predicted value: 0.2405096979562129
# Predicted value: -1.3047360198470415e-05
# Inverse transformed predicted value: -1.3047275082000986e-05
# Predicted value: -3.653159023997432e-05
# Inverse transformed predicted value: -3.653092296951321e-05
# Predicted value: 0.2148026586544347
# Inverse transformed predicted value: 0.2396172450917584
# Predicted value: 0.38898086099629836
# Inverse transformed predicted value: 0.4754763119162233
# Predicted value: 0.5086185185825798
# Inverse transformed predicted value: 0.6629922144705098
# Predicted value: 0.5693851935009206
# Inverse transformed predicted value: 0.7671802434809354
# Predicted value: 0.5824039147257736
# Inverse transformed predicted value: 0.790337079557047
# Predicted value: 0.5651578486974813
# Inverse transformed predicted value: 0.7597255311831439
# Predicted value: 0.5021037991666617
# Inverse transformed predicted value: 0.6521935002916797
# Predicted value: 0.3855626377655881
# Inverse transformed predicted value: 0.47044141461434474
# Predicted value: 0.21249338472603085
# Inverse transformed predicted value: 0.2367579320456692
# Predicted value: -4.04654967951501e-05
# Inverse transformed predicted value: -4.046467807794496e-05
# Predicted value: 5.4544306976822554e-05
# Inverse transformed predicted value: 5.4545794544669235e-05
# Predicted value: 0.21260935673831227
# Inverse transformed predicted value: 0.2369013696689677
# Predicted value: 0.38976793302549595
# Inverse transformed predicted value: 0.47663807518678913
# Predicted value: 0.5065275926569939
# Inverse transformed predicted value: 0.6595186536799071
# Predicted value: 0.5613362908131876
# Inverse transformed predicted value: 0.7530134716360439
# Predicted value: 0.5928440632501406
# Inverse transformed predicted value: 0.809126375432144
# Predicted value: 0.560488007605386
# Inverse transformed predicted value: 0.7515270502872737
# Predicted value: 0.5119229836880095
# Inverse transformed predicted value: 0.6684966037361972
# Predicted value: 0.39069043901713485
# Inverse transformed predicted value: 0.47800091117416343
# Predicted value: 0.21200135769663575
# Inverse transformed predicted value: 0.2361495633934676
# Predicted value: -0.00015979399563548213
# Inverse transformed predicted value: -0.00015978122925497384
# Predicted value: -7.157912136790401e-05
# Inverse transformed predicted value: -7.157655964373788e-05
# Predicted value: 0.22586849937556508
# Inverse transformed predicted value: 0.2534108301336262
# Predicted value: 0.38722477513852027
# Inverse transformed predicted value: 0.4728875225648488
# Predicted value: 0.5007497751264509
# Inverse transformed predicted value: 0.6499579044400265
# Predicted value: 0.5755107073366617
# Inverse transformed predicted value: 0.7780383523091519
# Predicted value: 0.5804820811561058
# Inverse transformed predicted value: 0.78689965379464
# Predicted value: 0.5706208155226022
# Inverse transformed predicted value: 0.7693651598934912
# Predicted value: 0.4976349329333516
# Inverse transformed predicted value: 0.6448265417837036
# Predicted value: 0.39772799803427006
# Inverse transformed predicted value: 0.4884391164755988
# Predicted value: 0.2241727882098985
# Inverse transformed predicted value: 0.25128720842718244
# Predicted value: -5.060337798568071e-06
# Inverse transformed predicted value: -5.060324995032062e-06
